# %% [markdown]
# <a href="https://colab.research.google.com/github/Ognejar/BookProject/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prepare

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install pygit2==1.19.0
# %cd /content
# !git clone https://github.com/mashb1t/Fooocus.git
# %cd /content/Fooocus
# !wget -O /content/Fooocus/models/loras/Hermione_Granger2.safetensors https://huggingface.co/nowisgame/lora/resolve/main/Hermione%20Granger2.safetensors

# %%
# Создание папки и копирование ВСЕХ LoRA
# !mkdir -p models/loras
# !cp -r /content/drive/MyDrive/Fooocus/models/loras/*.safetensors models/loras/ 2>/dev/null || echo "Копируются только .safetensors файлы"

# Проверка
# !ls models/loras/

# %% [markdown]
# Run

# %%
# !python entry_with_update.py --share --always-high-vram
